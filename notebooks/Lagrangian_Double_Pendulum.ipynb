# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from sympy.physics.mechanics import dynamicsymbols, init_vprinting #notation xdot theta dot instead of d/dt
from sympy import diff

# %% [markdown]
# Notation and Visualisation

# %%
# Das hier ist der entscheidende Befehl für die LaTeX-Ausgabe:
sp.init_printing(use_latex='mathjax')
init_vprinting() # Aktiviere die Punkt-Notation



t = sp.symbols('t')
x = dynamicsymbols('x')

# Wir bilden die zweite Ableitung nach der Zeit
beschleunigung = diff(x, t, t)

beschleunigung
